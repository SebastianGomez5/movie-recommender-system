# %%
import numpy as np
import pandas as pd
import ast

# %%
movies = pd.read_csv('sample_data/tmdb_5000_movies.csv')
credits = pd.read_csv('sample_data/tmdb_5000_credits.csv')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
#  15  status                4803 non-null   object
#  16  tagline               3959 non-null   object
#  17  title                 4803 non-null   object
#  18  vote_average          4803 non-null   float64
#  19  vote_count            4803 non-null   int64
# dtypes: float64(3), int64(4), object(13)
# memory usage: 750.6+ KB

# %%
credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4803 non-null   int64
#  1   title     4803 non-null   object
#  2   cast      4803 non-null   object
#  3   crew      4803 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 150.2+ KB

# %%
print(movies.shape) 
movies.head(1)
# Out:
# (4803, 20)
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
#                        tagline   title  vote_average  vote_count
# 0  Enter the World of Pandora.  Avatar           7.2       11800

# %%
print(credits.shape)
credits.head(1)
# Out:
# (4803, 4)
#    movie_id   title                                               cast  \
# 0     19995  Avatar  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...

# %%
credits = credits.rename(columns={'movie_id': 'id'})

# %%
# unir ambas tablas
movies = movies.merge(credits, on='id')
movies.head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  ... runtime  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
#                        tagline title_x vote_average vote_count title_y  \
# 0  Enter the World of Pandora.  Avatar          7.2      11800  Avatar
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
#
# [1 rows x 23 columns]

# %%
#Eliminar informacion con valores nulos
movies.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title_x                    0
# vote_average               0
# vote_count                 0
# title_y                    0
# cast                       0
# crew                       0
# dtype: int64

# %%
movies = movies.dropna()
movies.isnull().sum()
# Out:
# budget                  0
# genres                  0
# homepage                0
# id                      0
# keywords                0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# tagline                 0
# title_x                 0
# vote_average            0
# vote_count              0
# title_y                 0
# cast                    0
# crew                    0
# dtype: int64

# %%
#elegir columnas importantes
movies = movies[['id', 'original_title', 'overview', 'genres', 'keywords', 'cast', 'crew']]
movies.head(1)
# Out:
#       id original_title                                           overview  \
# 0  19995         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...

# %%
import ast # Para convertir cadenas de texto en listas
# Función para convertir texto en lista
def convert(text):
    L = []
    for i in ast.literal_eval(text):
        L.append(i['name'])
    return L

# %%
movies['genres'] = movies['genres'].apply(convert)
movies['keywords'] = movies['keywords'].apply(convert)
movies['cast'] = movies['cast'].apply(convert)
movies['crew'] = movies['crew'].apply(convert)

# %%
movies.head(1)
# Out:
#       id original_title                                           overview  \
# 0  19995         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
#
#                                                 cast  \
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weave...
#
#                                                 crew
# 0  [Stephen E. Rivkin, Rick Carter, Christopher B...

# %%
#Solo mostrar los primeros 3 actores del cast
movies['cast'] = movies['cast'].apply(lambda x: x[:3])
movies.head(2)
# Out:
#       id                            original_title  \
# 0  19995                                    Avatar
# 1    285  Pirates of the Caribbean: At World's End
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
#
#                                                cast  \
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weaver]
# 1     [Johnny Depp, Orlando Bloom, Keira Knightley]
#
#                                                 crew
# 0  [Stephen E. Rivkin, Rick Carter, Christopher B...
# 1  [Dariusz Wolski, Gore Verbinski, Jerry Bruckhe...

# %%
movies.sample(5)
# Out:
#           id                         original_title  \
# 1104   27573                      The Bounty Hunter
# 4772   42151                           Down Terrace
# 102   131634  The Hunger Games: Mockingjay - Part 2
# 778    11260                              Meet Dave
# 4464   14451                                Død snø
#
#                                                overview  \
# 1104  Milo Boyd is a bounty hunter whose latest gig ...
# 4772  After serving jail time for a mysterious crime...
# 102   With the nation of Panem in a full scale war, ...
# 778   A crew of miniature aliens operate a spaceship...
# 4464  Eight medical students on a ski trip to Norway...
#
#                                             genres  \
# 1104                                      [Action]
# 4772                       [Drama, Action, Comedy]
# 102           [Action, Adventure, Science Fiction]
# 778   [Comedy, Science Fiction, Adventure, Family]
# 4464                              [Horror, Comedy]
#
#                                                keywords  \
# 1104   [bounty hunter, ex-husband ex-wife relationship]
# 4772                [murder, dark comedy, crime family]
# 102   [revolution, strong woman, dystopia, game of d...
# 778   [new york, captain, starships, new love, earth...
# 4464                   [norway, undead, zombie, wintry]
#
#                                                    cast  \
# 1104       [Gerard Butler, Jennifer Aniston, Gio Perez]
# 4772            [Robert Hill, Robin Hill, Julia Deakin]
# 102   [Jennifer Lawrence, Josh Hutcherson, Liam Hems...
# 778    [Eddie Murphy, Elizabeth Banks, Gabrielle Union]
# 4464  [Charlotte Frogner, Stig Frode Henriksen, Vega...
#
#                                                    crew
# 1104  [George Fenton, Jane Musky, Neal H. Moritz, Tr...
# 4772           [Ben Wheatley, Ben Wheatley, Robin Hill]
# 102   [Debra Zane, James Newton Howard, Philip Messi...
# 778   [Arnon Milchan, Clay A. Griffith, John Debney,...
# 4464  [Stig Frode Henriksen, Tommy Wirkola, Tommy Wi...

# %%
#Aplicar la operacion a la columna overview para dividir cada resumen en palabras individuales
movies['overview'] = movies['overview'].apply(lambda x: x.split())
movies.sample(5)
# Out:
#          id                             original_title  \
# 3165   9400                                 Set It Off
# 4524  84401  Sholem Aleichem: Laughing In The Darkness
# 4240   1961                           My Name Is Bruce
# 1170   1213                    The Talented Mr. Ripley
# 3395  47088                              The Extra Man
#
#                                                overview  \
# 3165  [Four, black, women,, all, of, whom, have, suf...
# 4524  [A, riveting, portrait, of, the, great, writer...
# 4240  [B, Movie, Legend, Bruce, Campbell, is, mistak...
# 1170  [Tom, Ripley, is, a, calculating, young, man, ...
# 3395  [THE, EXTRA, MAN, is, a, sophisticated, and, m...
#
#                         genres  \
# 3165    [Drama, Action, Crime]
# 4524             [Documentary]
# 4240          [Comedy, Horror]
# 1170  [Thriller, Crime, Drama]
# 3395                  [Comedy]
#
#                                                keywords  \
# 3165  [single parent, bank robber, last chance, los ...
# 4524                                                 []
# 4240                           [parody, parallel world]
# 1170  [venice, italy, gay, new york, lovesickness, d...
# 3395                 [independent film, woman director]
#
#                                                    cast  \
# 3165  [Jada Pinkett Smith, Queen Latifah, Vivica A. ...
# 4524      [Rachel Dratch, Hillel Halkin, Jason Kravitz]
# 4240         [Bruce Campbell, Grace Thorsen, Ted Raimi]
# 1170            [Matt Damon, Gwyneth Paltrow, Jude Law]
# 3395             [Kevin Kline, Paul Dano, Katie Holmes]
#
#                                                    crew
# 3165  [Oren Koules, Christopher Young, John R. Carte...
# 4524                     [Joseph Dorman, Joseph Dorman]
# 4240   [Bruce Campbell, Bruce Campbell, Mark Verheiden]
# 1170  [Ronna Kress, Walter Murch, Walter Murch, Tom ...
# 3395  [Klaus Badelt, Anthony Bregman, Judy Becker, V...

# %%
# funcion para eliminar espacios 
def collapse(L):
    L1 = []
    for i in L:
        L1.append(i.replace(" ", ""))
    return L1


movies['keywords'] = movies['keywords'].apply(collapse)
movies['cast'] = movies['cast'].apply(collapse)
movies['crew'] = movies['crew'].apply(collapse)
movies['genres'] = movies['genres'].apply(collapse)

movies.head(1)
# Out:
#       id original_title                                           overview  \
# 0  19995         Avatar  [In, the, 22nd, century,, a, paraplegic, Marin...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
#
#                                             cast  \
# 0  [SamWorthington, ZoeSaldana, SigourneyWeaver]
#
#                                                 crew
# 0  [StephenE.Rivkin, RickCarter, ChristopherBoyes...

# %%
movies['tags'] = movies['overview'] + movies['genres'] + movies['keywords'] + movies['cast'] + movies['crew']
movies.head(3)
# Out:
#        id                            original_title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...
# 2  [spy, basedonnovel, secretagent, sequel, mi6, ...
#
#                                             cast  \
# 0  [SamWorthington, ZoeSaldana, SigourneyWeaver]
# 1     [JohnnyDepp, OrlandoBloom, KeiraKnightley]
# 2      [DanielCraig, ChristophWaltz, LéaSeydoux]
#
#                                                 crew  \
# 0  [StephenE.Rivkin, RickCarter, ChristopherBoyes...
# 1  [DariuszWolski, GoreVerbinski, JerryBruckheime...
# 2  [ThomasNewman, SamMendes, AnnaPinnock, JohnLog...
#
#                                                 tags
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...

# %%
movies_new = movies[['id', 'original_title', 'tags']]
movies_new.head(3)
# Out:
#        id                            original_title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
#
#                                                 tags
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...

# %%
# hacer que tags no sea una lista
movies_new['tags'] = movies_new['tags'].apply(lambda x: ' '.join(x))
movies_new.head(3)
# Out:
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_14268\2861012923.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_new['tags'] = movies_new['tags'].apply(lambda x: ' '.join(x))
#        id                            original_title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
#
#                                                 tags
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...

# %% [markdown]
# ### Creacion del modelo de Maching Learning

# %%
from sklearn.feature_extraction.text import CountVectorizer

#cv = CountVectorizer()
#count_matrix = cv.fit_transform(movies_new['tags'])
